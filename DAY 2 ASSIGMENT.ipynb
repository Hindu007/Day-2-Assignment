# %%
import random

maxTicketsAvailable = int(input("Enter the maximum tickets available = "))

noofparticipants = []

for temp in range(maxTicketsAvailable):
  st = "Enter the Participant name - "+ str(temp + 1) + " = "
  name = input(st)
  noofparticipants.append(name)

print("All our participants - ",noofparticipants)

n = random.randint(0,maxTicketsAvailable-1)

print("Winner of the lottery - ",noofparticipants[n])
# Out:
# Enter the maximum tickets available = 7
# Enter the Participant name - 1 = minmin
# Enter the Participant name - 2 = bongbong
# Enter the Participant name - 3 = tae
# Enter the Participant name - 4 = vinzenzo
# Enter the Participant name - 5 = lee min ho
# Enter the Participant name - 6 = goblin
# Enter the Participant name - 7 = dhoni mSD
# All our participants -  ['minmin', 'bongbong', 'tae', 'vinzenzo', 'lee min ho', 'goblin', 'dhoni mSD']
# Winner of the lottery -  minmin
